# %% [markdown]
# <a href="https://colab.research.google.com/github/Jason04-08-2005/data-science-lab/blob/main/Unsupervised_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
from google.colab import files
uploaded=files.upload()
df=pd.read_csv("Mall_Customers.csv")
print(df.head())
# Out:
#      <input type="file" id="files-c4de06d2-814d-40aa-8ea1-c3fe1a90e56e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c4de06d2-814d-40aa-8ea1-c3fe1a90e56e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None

# %%
sns.pairplot(df[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']])
plt.show()

# %%
plt.scatter(df ['Age'], df ['Annual Income (k$)'])
plt.xlabel('Age')
plt.ylabel('Annual Income')
plt.show()

# %%
plt.scatter(df ['Annual Income (k$)'], df ['Spending Score (1-100)'])
plt.xlabel('Age')
plt.ylabel('Annual Income')
plt.show()

# %%
X=df ['Annual Income (k$)'], df ['Spending Score (1-100)']

# %%
from sklearn.cluster import KMeans
WCSS=[]

for i in range(1,11):
  A=KMeans(n_clusters=i)
  A.fit(X)
  WCSS.append(A.inertia_)
plt.plot(range(1,11),WCSS)
plt.tittle('The Elbow Metod')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-77536de25793> in <cell line: 0>()
#       4 for i in range(1,11):
#       5   A=KMeans(n_clusters=i)
# ----> 6   A.fit(X)
#       7   WCSS.append(A.inertia_)
#       8 plt.plot(range(1,11),WCSS)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1462         )
#    1463
# -> 1464         self._check_params_vs_input(X)
#    1465
#    1466         random_state = check_random_state(self.random_state)
#
# ...
